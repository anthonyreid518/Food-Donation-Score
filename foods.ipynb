# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/4rc3ue7y43lgazmy44xhxpn32mfujo')

# %%
df.head()
# Out:
#      ID               FoodGroup              ShortDescrip  \
# 0  1001  Dairy and Egg Products          BUTTER,WITH SALT
# 1  1002  Dairy and Egg Products  BUTTER,WHIPPED,WITH SALT
# 2  1003  Dairy and Egg Products      BUTTER OIL,ANHYDROUS
# 3  1004  Dairy and Egg Products               CHEESE,BLUE
# 4  1005  Dairy and Egg Products              CHEESE,BRICK
#
#                       Descrip CommonName MfgName ScientificName  Energy_kcal  \
# 0              Butter, salted        NaN     NaN            NaN        717.0
# 1  Butter, whipped, with salt        NaN     NaN            NaN        717.0
# 2       Butter oil, anhydrous        NaN     NaN            NaN        876.0
# 3                Cheese, blue        NaN     NaN            NaN        353.0
# 4               Cheese, brick        NaN     NaN            NaN        371.0
#
#    Protein_g  Fat_g  ...  Folate_USRDA  Niacin_USRDA  Riboflavin_USRDA  \
# 0       0.85  81.11  ...        0.0075      0.002625          0.026154
# ...

# %%
df['FoodGroup'].value_counts()
# Out:
# Beef Products                          946
# Vegetables and Vegetable Products      828
# Baked Products                         797
# Soups, Sauces, and Gravies             452
# Lamb, Veal, and Game Products          438
# Poultry Products                       390
# Legumes and Legume Products            389
# Fast Foods                             371
# Breakfast Cereals                      363
# Baby Foods                             362
# Sweets                                 347
# Fruits and Fruit Juices                346
# Pork Products                          343
# Beverages                              315
# Finfish and Shellfish Products         267
# Dairy and Egg Products                 264
# Sausages and Luncheon Meats            244
# Fats and Oils                          219
# Cereal Grains and Pasta                183
# Snacks                                 171
# American Indian/Alaska Native Foods    165
# Nut and Seed Products                  133
# ...

# %%
df.columns
# Out:
# Index(['ID', 'FoodGroup', 'ShortDescrip', 'Descrip', 'CommonName', 'MfgName',
#        'ScientificName', 'Energy_kcal', 'Protein_g', 'Fat_g', 'Carb_g',
#        'Sugar_g', 'Fiber_g', 'VitA_mcg', 'VitB6_mg', 'VitB12_mcg', 'VitC_mg',
#        'VitE_mg', 'Folate_mcg', 'Niacin_mg', 'Riboflavin_mg', 'Thiamin_mg',
#        'Calcium_mg', 'Copper_mcg', 'Iron_mg', 'Magnesium_mg', 'Manganese_mg',
#        'Phosphorus_mg', 'Selenium_mcg', 'Zinc_mg', 'VitA_USRDA', 'VitB6_USRDA',
#        'VitB12_USRDA', 'VitC_USRDA', 'VitE_USRDA', 'Folate_USRDA',
#        'Niacin_USRDA', 'Riboflavin_USRDA', 'Thiamin_USRDA', 'Calcium_USRDA',
#        'Copper_USRDA', 'Magnesium_USRDA', 'Phosphorus_USRDA', 'Selenium_USRDA',
#        'Zinc_USRDA'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8618 entries, 0 to 8617
# Data columns (total 45 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                8618 non-null   int64
#  1   FoodGroup         8618 non-null   object
#  2   ShortDescrip      8618 non-null   object
#  3   Descrip           8618 non-null   object
#  4   CommonName        1063 non-null   object
#  5   MfgName           1560 non-null   object
#  6   ScientificName    732 non-null    object
#  7   Energy_kcal       8618 non-null   float64
#  8   Protein_g         8618 non-null   float64
#  9   Fat_g             8618 non-null   float64
#  10  Carb_g            8618 non-null   float64
#  11  Sugar_g           8618 non-null   float64
#  12  Fiber_g           8618 non-null   float64
#  13  VitA_mcg          8618 non-null   float64
#  14  VitB6_mg          8618 non-null   float64
#  15  VitB12_mcg        8618 non-null   float64
# ...

# %%
df_new = pd.read_excel('https://query.data.world/s/twh3fzbktso2x5z5dlr7yal2ntdfks')

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 53 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NDB_No             8790 non-null   int64
#  1   Shrt_Desc          8790 non-null   object
#  2   Water_(g)          8789 non-null   float64
#  3   Energ_Kcal         8790 non-null   int64
#  4   Protein_(g)        8790 non-null   float64
#  5   Lipid_Tot_(g)      8790 non-null   float64
#  6   Ash_(g)            8465 non-null   float64
#  7   Carbohydrt_(g)     8790 non-null   float64
#  8   Fiber_TD_(g)       8196 non-null   float64
#  9   Sugar_Tot_(g)      6958 non-null   float64
#  10  Calcium_(mg)       8442 non-null   float64
#  11  Iron_(mg)          8646 non-null   float64
#  12  Magnesium_(mg)     8051 non-null   float64
#  13  Phosphorus_(mg)    8211 non-null   float64
#  14  Potassium_(mg)     8364 non-null   float64
# ...

# %%
df_new.head()
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  ...  \
# 0          81.11     2.11            0.06           0.0           0.06  ...
# 1          78.30     1.62            2.87           0.0           0.06  ...
# 2          99.48     0.00            0.00           0.0           0.00  ...
# 3          28.74     5.11            2.34           0.0           0.50  ...
# 4          29.68     3.18            2.79           0.0           0.51  ...
#
#    Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)  GmWt_1  \
# ...

# %%
final_df = pd.merge(left=df[['ID', 'FoodGroup', 'CommonName']], right=df_new, left_on = 'ID',right_on ='NDB_No', how='right').drop(columns='ID')

# %%
final_df.head(1)
# Out:
#                 FoodGroup CommonName  NDB_No         Shrt_Desc  Water_(g)  \
# 0  Dairy and Egg Products        NaN    1001  BUTTER,WITH SALT      15.87
#
#    Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  ...  \
# 0         717         0.85          81.11     2.11            0.06  ...
#
#    Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)  GmWt_1  \
# 0         7.0      51.368       21.021        3.043           215.0     5.0
#
#                    GmWt_Desc1  GmWt_2  GmWt_Desc2  Refuse_Pct
# 0  1 pat,  (1" sq, 1/3" high)    14.2      1 tbsp         0.0
#
# [1 rows x 55 columns]

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8790 entries, 0 to 8789
# Data columns (total 56 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 8419 non-null   float64
#  1   FoodGroup          8419 non-null   object
#  2   CommonName         1049 non-null   object
#  3   NDB_No             8790 non-null   int64
#  4   Shrt_Desc          8790 non-null   object
#  5   Water_(g)          8789 non-null   float64
#  6   Energ_Kcal         8790 non-null   int64
#  7   Protein_(g)        8790 non-null   float64
#  8   Lipid_Tot_(g)      8790 non-null   float64
#  9   Ash_(g)            8465 non-null   float64
#  10  Carbohydrt_(g)     8790 non-null   float64
#  11  Fiber_TD_(g)       8196 non-null   float64
#  12  Sugar_Tot_(g)      6958 non-null   float64
#  13  Calcium_(mg)       8442 non-null   float64
#  14  Iron_(mg)          8646 non-null   float64
# ...

# %%
final_df['canned'] = [1  if "canned" in item.lower() else 0 for item in final_df['Shrt_Desc']]

# %%
final_df.head(2)
# Out:
#                 FoodGroup CommonName  NDB_No               Shrt_Desc  \
# 0  Dairy and Egg Products        NaN    1001        BUTTER,WITH SALT
# 1  Dairy and Egg Products        NaN    1002  BUTTER,WHIPPED,W/ SALT
#
#    Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  \
# 0      15.87         717         0.85          81.11     2.11            0.06
# 1      16.72         718         0.49          78.30     1.62            2.87
#
#    ...  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)  GmWt_1  \
# 0  ...      51.368       21.021        3.043           215.0     5.0
# 1  ...      45.390       19.874        3.331           225.0     3.8
#
#                    GmWt_Desc1  GmWt_2  GmWt_Desc2  Refuse_Pct  canned
# 0  1 pat,  (1" sq, 1/3" high)    14.2      1 tbsp         0.0       0
# 1  1 pat,  (1" sq, 1/3" high)     9.4      1 tbsp         0.0       0
#
# [2 rows x 56 columns]

# %%
#view canned foods

final_df[final_df['canned']==1]
# Out:
#                               FoodGroup CommonName  NDB_No  \
# 302                    Spices and Herbs        NaN    2054
# 1043                   Poultry Products        NaN    5311
# 1271         Soups, Sauces, and Gravies        NaN    6114
# 1278         Soups, Sauces, and Gravies        NaN    6121
# 1640        Sausages and Luncheon Meats        NaN    7026
# 1641        Sausages and Luncheon Meats        NaN    7027
# 1656        Sausages and Luncheon Meats        NaN    7045
# 1661        Sausages and Luncheon Meats        NaN    7053
# 2306            Fruits and Fruit Juices        NaN    9229
# 2366            Fruits and Fruit Juices        NaN    9294
# 2886  Vegetables and Vegetable Products        NaN   11108
# 3143  Vegetables and Vegetable Products        NaN   11426
# 3297  Vegetables and Vegetable Products        NaN   11655
# 3315  Vegetables and Vegetable Products        NaN   11693
# 3460  Vegetables and Vegetable Products        NaN   11846
# ...

# %%
final_df['CommonName'].value_counts()
# Out:
# hamburger                                  25
# KFC                                        22
# family style                               21
# buffalo                                    13
# soft drink, pop, soda                      13
#                                            ..
# IMPS # 1309A                                1
# includes USDA Commodity B856                1
# platanos maduros                            1
# Includes USDA commodity food A255, A263     1
# Includes USDA commodity food A214           1
# Name: CommonName, Length: 440, dtype: int64
